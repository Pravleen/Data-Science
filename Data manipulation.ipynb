# %%
import pandas as pd

# %%
titanic=pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic[['Name','Sex','Ticket','Cabin','Embarked']].describe()
# Out:
#                                Name   Sex  Ticket        Cabin Embarked
# count                           156   156     156           31      155
# unique                          156     2     145           28        3
# top     White, Mr. Percival Wayland  male  113803  C23 C25 C27        S
# freq                              1   100       2            2      110

# %%
titanic.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
s=titanic.dtypes[titanic.dtypes=="object"]

# %%
titanic[s.index].describe()
# Out:
#                                Name   Sex  Ticket        Cabin Embarked
# count                           156   156     156           31      155
# unique                          156     2     145           28        3
# top     White, Mr. Percival Wayland  male  113803  C23 C25 C27        S
# freq                              1   100       2            2      110

# %%
titanic["Name"] #SORTING OF COLUMNS
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 151                    Pears, Mrs. Thomas (Edith Wearne)
# 152                                     Meo, Mr. Alfonzo
# 153                      van Billiard, Mr. Austin Blyler
# 154                                Olsen, Mr. Ole Martin
# 155                          Williams, Mr. Charles Duane
# Name: Name, Length: 156, dtype: object

# %%
sorted(titanic["Name"]) #SORTING OF COLUMNS
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Attalah, Miss. Malake',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Barton, Mr. David John',
#  'Bateman, Rev. Robert James',
#  'Baxter, Mr. Quigg Edmond',
#  'Beesley, Mr. Lawrence',
#  'Bing, Mr. Lee',
#  'Bonnell, Miss. Elizabeth',
#  'Boulos, Mrs. Joseph (Sultana)',
#  'Braund, Mr. Owen Harris',
#  'Burke, Mr. Jeremiah',
#  'Byles, Rev. Thomas Roussel Davids',
#  'Caldwell, Master. Alden Gates',
#  'Cann, Mr. Ernest Charles',
#  'Carrau, Mr. Francisco M',
#  'Celotti, Mr. Francesco',
#  'Chaffee, Mr. Herbert Fuller',
# ...

# %%
type(sorted(titanic["Name"]))
# Out:
# list

# %%
sorted(titanic["Name"])[100:150:2]
# Out:
# ['Novel, Mr. Mansouer',
#  'Nysten, Miss. Anna Sofia',
#  'O\'Dwyer, Miss. Ellen "Nellie"',
#  'Osen, Mr. Olaf Elon',
#  'Palsson, Master. Gosta Leonard',
#  'Panula, Master. Juha Niilo',
#  'Pekoniemi, Mr. Edvard',
#  'Petranec, Miss. Matilda',
#  'Porter, Mr. Walter Chamberlain',
#  'Rice, Master. Eugene',
#  'Robins, Mrs. Alexander A (Grace Charity Laury)',
#  'Rugg, Miss. Emily',
#  'Samaan, Mr. Youssef',
#  'Saundercock, Mr. William Henry',
#  'Shorney, Mr. Charles Joseph',
#  'Skoog, Master. Harald',
#  'Sloper, Mr. William Thompson',
#  'Spencer, Mrs. William Augustus (Marie Eugenie)',
#  'Stewart, Mr. Albert A',
#  'Turpin, Mr. William John Robert',
#  'Uruchurtu, Don. Manuel E',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Waelens, Mr. Achille',
#  'Weisz, Mrs. Leopold (Mathilde Francoise Pede)',
#  'Wheadon, Mr. Edward H']

# %% [markdown]
# #Practice Questions <br>
# 1.Read a data<br>
# 2.Select ticket as a df<br>
# 3.Select Fare and class and find description<br>
# 4.Select survived,pclass and sort it<br>
# 5.Select name starting with s<br>

# %%
data=pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')

# %%
df=data[["Ticket"]]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data[["Fare","Pclass"]].describe()
# Out:
#              Fare      Pclass
# count  156.000000  156.000000
# mean    28.109587    2.423077
# std     39.401047    0.795459
# min      6.750000    1.000000
# 25%      8.003150    2.000000
# 50%     14.454200    3.000000
# 75%     30.371850    3.000000
# max    263.000000    3.000000

# %%
sorted(data[["Survived","Pclass"]])
# Out:
# ['Pclass', 'Survived']

# %%
data[["Survived","Pclass"]].sort_values
# Out:
# <bound method DataFrame.sort_values of      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 151         1       1
# 152         0       3
# 153         0       3
# 154         0       3
# 155         0       1
#
# [156 rows x 2 columns]>

# %%
data["Name"].str.startswith('S') #this will just print the true false
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Name, Length: 156, dtype: bool

# %%
a=data["Name"]
for i in a:
    if i[0][0]=='S':
        print(i)
# Out:
# Sandstrom, Miss. Marguerite Rut
# Saundercock, Mr. William Henry
# Sloper, Mr. William Thompson
# Spencer, Mrs. William Augustus (Marie Eugenie)
# Samaan, Mr. Youssef
# Sirayanian, Mr. Orsen
# Skoog, Master. Harald
# Stewart, Mr. Albert A
# Staneff, Mr. Ivan
# Sheerlinck, Mr. Jan Baptist
# Slocovski, Mr. Selman Francis
# Shorney, Mr. Charles Joseph
# Salkjelsvik, Miss. Anna Kristine
# Sobey, Mr. Samuel James Hayden

# %% [markdown]
# #### add a column

# %%
titanic["New"]=0

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New
# 0      0         A/5 21171   7.2500   NaN        S    0
# 1      0          PC 17599  71.2833   C85        C    0
# 2      0  STON/O2. 3101282   7.9250   NaN        S    0
# 3      0            113803  53.1000  C123        S    0
# ...

# %%
titanic["SibSp"]=0

# %%
titanic["Pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 151    1
# 152    3
# 153    3
# 154    3
# 155    1
# Name: Pclass, Length: 156, dtype: int64

# %%
pd.Categorical(titanic["Pclass"])
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
titanic["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
titanic["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
import numpy as np

# %%
titanic["Cabin"]
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 151      C2
# 152     NaN
# 153     NaN
# 154     NaN
# 155     NaN
# Name: Cabin, Length: 156, dtype: object

# %%
type(titanic["Cabin"][0])
# Out:
# float

# %%
#convert the type of entire column
titanic["Cabin"].astype(str)
# Out:
# 0       nan
# 1       C85
# 2       nan
# 3      C123
# 4       nan
#        ...
# 151      C2
# 152     nan
# 153     nan
# 154     nan
# 155     nan
# Name: Cabin, Length: 156, dtype: object

# %%
s=titanic["Cabin"].astype(str)

# %%
type(s[0])
# Out:
# str

# %%
new_cabin=[cabin[0] for cabin in s]

# %%
new_cabin #printing all the first char of the particular column
# Out:
# ['n',
#  'C',
#  'n',
#  'C',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'G',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'A',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'A',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'E',
#  'D',
# ...

# %%
pd.Categorical(i[0] for i in titanic["Name"])
# Out:
# [B, C, H, F, A, ..., P, M, v, O, W]
# Length: 156
# Categories (24, object): [A, B, C, D, ..., V, W, Z, v]

# %%
pd.Series(i[0] for i in titanic["Name"]).unique()
# Out:
# array(['B', 'C', 'H', 'F', 'A', 'M', 'P', 'J', 'N', 'S', 'V', 'R', 'W',
#        'E', 'O', 'T', 'U', 'G', 'K', 'L', 'D', 'I', 'Z', 'v'],
#       dtype=object)

# %%
titanic["Age"].isnull
# Out:
# <bound method Series.isnull of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 151    22.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 156, dtype: float64>

# %%
np.where(titanic["Age"].isnull()==True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
index_value=np.where(titanic["Age"].isnull()==True)

# %%
titanic.iloc[index_value]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
max_fare=np.where(data["Fare"]==max(data["Fare"]))

# %%
data.iloc[max_fare]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S

# %%
data.iloc[max_fare]["Name"]
# Out:
# 27    Fortune, Mr. Charles Alexander
# 88        Fortune, Miss. Mabel Helen
# Name: Name, dtype: object

# %%
data["family"]=data["SibSp"]+data["Parch"]

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Ques If the fare and age is minimum filter out the name and age of that person

# %%
titanic.iloc[np.where((titanic["Fare"]== min(titanic["Fare"])) & (titanic["Age"]==min(titanic["Age"])))]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, New]
# Index: []

# %% [markdown]
# Ques If the fare and age is greater than 30 filter out the name and age of that person

# %%
b=np.where(((titanic["Age"])>30 )&(titanic["Fare"]== min(titanic["Fare"])))

# %%
titanic.iloc[b][["Name","Age"]]
# Out:
# Empty DataFrame
# Columns: [Name, Age]
# Index: []
